# %% [markdown]
# # Doctor's Prescription — Notebook
# This notebook delegates heavy preprocessing and model training to external scripts to keep kernels stable.
#
# How to run on Kaggle: The notebook prefers a top-level `run_kaggle.py` (or the Kaggle utility path like `/kaggle/usr/lib/run_kaggle/run_kaggle.py`).
#
# To run everything from this notebook: execute the code cell labeled "Launch full pipeline" — it invokes the orchestrator using the current Python executable and will run preprocess → train → convert.
#
# Tip: keep heavy imports (transformers/tokenizers) in the consolidated imports cell and run it only when needed.

# %%
# Consolidated imports — run this cell first
# --- Standard library ---
import os
import json
import gc
import glob
import time
import sys
import subprocess
from pathlib import Path

# --- Data science ---
import pandas as pd
import numpy as np

# --- Imaging / visualization ---
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# --- OCR / utilities ---
import pytesseract
import joblib
import psutil

# --- ML frameworks ---
import tensorflow as tf
import torch

# --- Scikit-learn ---
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# --- Transformers / Tokenizers (heavy) ---
# These are included here to keep all imports in one place; run this cell only when needed
from transformers import (
    BertTokenizerFast,
    BertConfig,
    BertForMaskedLM,
    AdamW,
    Trainer,
    TrainingArguments,
    DataCollatorForSeq2Seq,
)
from torch.utils.data import Dataset
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.pre_tokenizers import Whitespace
from tokenizers.trainers import WordLevelTrainer

# End of imports

# %%
# Setup constants and environment for Kaggle
# Default dataset root used in scripts/run_kaggle.py
DATASET_ROOT = '/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset'
PROCESSED_DIR = Path('data/processed')
WORK_DIR = Path('/kaggle/working')

# Scripts location detection (supports Kaggle utility paths and dataset inputs)
SCRIPTS_DIR = Path('scripts')
# If `scripts/` isn't present (common on Kaggle), prefer Kaggle utility layout under /kaggle/usr/lib
if not SCRIPTS_DIR.exists():
    # First, check for Kaggle utility scripts under /kaggle/usr/lib (e.g. /kaggle/usr/lib/train_cnn/train_cnn.py)
    kaggle_utils = glob.glob('/kaggle/usr/lib/**/run_kaggle.py', recursive=True) + glob.glob('/kaggle/usr/lib/**/train_cnn.py', recursive=True) + glob.glob('/kaggle/usr/lib/**/load_images.py', recursive=True)
    if kaggle_utils:
        SCRIPTS_DIR = Path(kaggle_utils[0]).parent
    else:
        # Look for a 'scripts' folder inside added Kaggle input datasets
        candidates = glob.glob('/kaggle/input/**/scripts', recursive=True)
        if candidates:
            SCRIPTS_DIR = Path(candidates[0])
        else:
            # Fallback: if our individual script files exist in a dataset, use that parent
            candidates2 = glob.glob('/kaggle/input/**/train_cnn.py', recursive=True)
            if candidates2:
                SCRIPTS_DIR = Path(candidates2[0]).parent
            else:
                # No scripts folder found — use repository root so Path('train_cnn.py') will be resolved
                SCRIPTS_DIR = Path('.')

print('DATASET_ROOT =', DATASET_ROOT)
print('PROCESSED_DIR =', PROCESSED_DIR)
print('WORK_DIR =', WORK_DIR)
print('SCRIPTS_DIR =', SCRIPTS_DIR)
# Out:
# DATASET_ROOT = /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset
# PROCESSED_DIR = data/processed
# WORK_DIR = /kaggle/working
# SCRIPTS_DIR = /kaggle/usr/lib/run_kaggle

# %%
# Helper: resolve script path from common locations (repo root, /kaggle/usr/lib/<name>/, SCRIPTS_DIR, /kaggle/input)**)
def resolve_script(script_name, prefer_usr_lib=True):
    """Return a Path to an existing script, preferring locations in this order:\n    1) repo root Path(script_name)\n    2) /kaggle/usr/lib/<stem>/<script_name> (if prefer_usr_lib)\n    3) SCRIPTS_DIR / script_name (if SCRIPTS_DIR exists)\n    4) any /kaggle/input/**/script_name match\    Raises FileNotFoundError if none found."""
    candidates = []
    # 1) repo root (project-local)
    candidates.append(Path(script_name))
    # 2) Kaggle utility layout: /kaggle/usr/lib/<stem>/<script_name>
    stem = Path(script_name).stem
    if prefer_usr_lib:
        candidates.append(Path(f'/kaggle/usr/lib/{stem}/{script_name}'))
    # 3) scripts dir discovered earlier
    try:
        if 'SCRIPTS_DIR' in globals() and SCRIPTS_DIR is not None:
            candidates.append(SCRIPTS_DIR / script_name)
    except Exception:
        pass
    # 4) search in /kaggle/input/**
    matches = glob.glob(f'/kaggle/input/**/{script_name}', recursive=True)
    for m in matches:
        candidates.append(Path(m))
    # Return first existing candidate
    for p in candidates:
        try:
            if p.exists():
                return p
        except Exception:
            continue
    raise FileNotFoundError(f'Script {script_name} not found in candidates: {candidates}')

# Quick check helper
def print_resolved(script_name):
    try:
        p = resolve_script(script_name)
        print(f'Resolved {script_name} ->', p)
    except FileNotFoundError as e:
        print(e)

# %%
# Load `history` and `test` produced by external scripts (early loader)
# This loader attempts to find artifacts produced by external scripts but does not fail early;
# training or preprocessing cells will generate these during the run.
history = None
test = None
PROCESSED_DIR = Path('data/processed')
try:
    WORK_DIR = Path('/kaggle/working')
except Exception:
    WORK_DIR = Path('.')
# Look for any model-adjacent history files first
hist_candidates = []
if WORK_DIR.exists():
    hist_candidates = sorted(WORK_DIR.glob('*.history.json'))
if not hist_candidates:
    hist_candidates = sorted(Path('.').glob('*.history.json'))
if hist_candidates:
    try:
        with open(hist_candidates[0]) as f:
            hist_dict = json.load(f)
        class HistoryWrapper:
            def __init__(self, d):
                self.history = d
        history = HistoryWrapper(hist_dict)
        print('Loaded training history from', hist_candidates[0])
    except Exception as e:
        print('Failed to load history:', e)
# Also try a deterministic history path written by the training script (if present)
if history is None:
    try:
        alt_hist = Path('/kaggle/working/prescription_classification_history.json')
        if alt_hist.exists():
            with open(alt_hist) as f:
                hist_dict = json.load(f)
            class HistoryWrapper:
                def __init__(self, d):
                    self.history = d
            history = HistoryWrapper(hist_dict)
            print('Loaded deterministic training history from', alt_hist)
    except Exception as e:
        print('Failed to load deterministic history:', e)
# Try to load test samples saved by preprocessing (data/processed/test_samples.npz)
test_paths = [PROCESSED_DIR / 'test_samples.npz', WORK_DIR / 'test_samples.npz', PROCESSED_DIR / 'test_samples.npy', WORK_DIR / 'test_samples.npy']
for tp in test_paths:
    try:
        tp = Path(tp)
        if tp.exists():
            if tp.suffix == '.npz':
                loaded = np.load(tp)
                test = loaded.get('test')
            else:
                test = np.load(tp)
            print('Loaded test samples from', tp)
            break
    except Exception as e:
        print('Failed loading test samples from', tp, e)
if test is None:
    print('No test samples found yet; latency benchmarks will run after preprocessing.')
# Out:
# No test samples found yet; latency benchmarks will run after preprocessing.

# %%
# Launch full pipeline (preprocess -> train -> convert) — robust runner
print('Launching full pipeline via run_kaggle.py')
# Try resolving orchestrator via resolve_script and run it (capturing output)
try:
    script_path = resolve_script('run_kaggle.py')
    print('Using orchestrator:', script_path)
    try:
        result = subprocess.run([sys.executable, str(script_path)], capture_output=True, text=True, check=True)
        print('Orchestrator completed successfully:', script_path)
        if result.stdout:
            print('--- orchestrator stdout ---')
            print(result.stdout)
        if result.stderr:
            print('--- orchestrator stderr ---')
            print(result.stderr)
    except subprocess.CalledProcessError as e:
        print(f'Orchestrator {script_path} failed with returncode {e.returncode}')
        print('--- captured stdout ---')
        print(e.stdout if e.stdout else '<no stdout>')
        print('--- captured stderr ---')
        print(e.stderr if e.stderr else '<no stderr>')
        raise
except FileNotFoundError as e:
    print(e)
    raise
# Out:
# Launching full pipeline via run_kaggle.py
# Using orchestrator: /kaggle/usr/lib/run_kaggle/run_kaggle.py
# Orchestrator completed successfully: /kaggle/usr/lib/run_kaggle/run_kaggle.py
# --- orchestrator stdout ---
# Saved processed images and labels to data/processed
# Found 3120 validated image filenames belonging to 78 classes.
# Found 780 validated image filenames belonging to 78 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 82, 82, 16)        448
#
#  max_pooling2d (MaxPooling2  (None, 41, 41, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 39, 39, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 19, 19, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 17, 17, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 78)                20046
#
# =================================================================
# Total params: 1092462 (4.17 MB)
# Trainable params: 1092462 (4.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
#
#  1/25 [>.............................] - ETA: 7:05 - loss: 4.3788 - accuracy: 0.0078
#  2/25 [=>............................] - ETA: 9s - loss: 4.3909 - accuracy: 0.0078
#  3/25 [==>...........................] - ETA: 9s - loss: 4.3857 - accuracy: 0.0130
#  4/25 [===>..........................] - ETA: 8s - loss: 4.3832 - accuracy: 0.0098
#  5/25 [=====>........................] - ETA: 7s - loss: 4.3828 - accuracy: 0.0094
#  6/25 [======>.......................] - ETA: 7s - loss: 4.3779 - accuracy: 0.0117
#  7/25 [=======>......................] - ETA: 6s - loss: 4.3772 - accuracy: 0.0112
#  8/25 [========>.....................] - ETA: 6s - loss: 4.3754 - accuracy: 0.0117
#  9/25 [=========>....................] - ETA: 6s - loss: 4.3725 - accuracy: 0.0139
# 10/25 [===========>..................] - ETA: 5s - loss: 4.3731 - accuracy: 0.0133
# 11/25 [============>.................] - ETA: 5s - loss: 4.3747 - accuracy: 0.0121
# 12/25 [=============>................] - ETA: 5s - loss: 4.3743 - accuracy: 0.0130
# 13/25 [==============>...............] - ETA: 4s - loss: 4.3733 - accuracy: 0.0144
# 23/25 [==========================>...] - ETA: 0s - loss: 3.1691 - accuracy: 0.2517
# 24/25 [===========================>..] - ETA: 0s - loss: 3.1594 - accuracy: 0.2543
# 25/25 [==============================] - ETA: 0s - loss: 3.1596 - accuracy: 0.2529
# 25/25 [==============================] - 10s 397ms/step - loss: 3.1596 - accuracy: 0.2529 - val_loss: 3.0769 - val_accuracy: 0.3013
# Epoch 15/15
#
#  1/25 [>.............................] - ETA: 10s - loss: 3.0915 - accuracy: 0.2656
#  2/25 [=>............................] - ETA: 8s - loss: 3.1567 - accuracy: 0.2500
#  3/25 [==>...........................] - ETA: 8s - loss: 3.1410 - accuracy: 0.2578
#  4/25 [===>..........................] - ETA: 7s - loss: 3.1113 - accuracy: 0.2520
#  5/25 [=====>........................] - ETA: 7s - loss: 3.0976 - accuracy: 0.2531
#  6/25 [======>.......................] - ETA: 7s - loss: 3.0956 - accuracy: 0.2500
#  7/25 [=======>......................] - ETA: 6s - loss: 3.0889 - accuracy: 0.2578
#  8/25 [========>.....................] - ETA: 6s - loss: 3.0756 - accuracy: 0.2598
#  9/25 [=========>....................] - ETA: 6s - loss: 3.0838 - accuracy: 0.2578
# 10/25 [===========>..................] - ETA: 5s - loss: 3.0896 - accuracy: 0.2602
# 11/25 [============>.................] - ETA: 5s - loss: 3.0821 - accuracy: 0.2642
# 12/25 [=============>................] - ETA: 4s - loss: 3.0814 - accuracy: 0.2689
# 13/25 [==============>...............] - ETA: 4s - loss: 3.0836 - accuracy: 0.2662
# 14/25 [===============>..............] - ETA: 4s - loss: 3.0769 - accuracy: 0.2667
# 15/25 [=================>............] - ETA: 3s - loss: 3.0909 - accuracy: 0.2646
# 16/25 [==================>...........] - ETA: 3s - loss: 3.0941 - accuracy: 0.2612
# 17/25 [===================>..........] - ETA: 2s - loss: 3.0808 - accuracy: 0.2624
# 18/25 [====================>.........] - ETA: 2s - loss: 3.0798 - accuracy: 0.2613
# 19/25 [=====================>........] - ETA: 2s - loss: 3.0797 - accuracy: 0.2595
# 20/25 [=======================>......] - ETA: 1s - loss: 3.0758 - accuracy: 0.2598
# 21/25 [========================>.....] - ETA: 1s - loss: 3.0724 - accuracy: 0.2600
# 22/25 [=========================>....] - ETA: 1s - loss: 3.0700 - accuracy: 0.2642
# 23/25 [==========================>...] - ETA: 0s - loss: 3.0673 - accuracy: 0.2636
# 24/25 [===========================>..] - ETA: 0s - loss: 3.0671 - accuracy: 0.2624
# 25/25 [==============================] - ETA: 0s - loss: 3.0629 - accuracy: 0.2654
# 25/25 [==============================] - 10s 395ms/step - loss: 3.0629 - accuracy: 0.2654 - val_loss: 2.9875 - val_accuracy: 0.3154
# Saved training history to /kaggle/working/prescription_classification_model.h5.history.json and /kaggle/working/prescription_classification_history.json
# Saved model to /kaggle/working/prescription_classification_model.h5
# Saved TFLite to /kaggle/working/prescription_classification_quantized.tflite
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 84, 32)            36480
#
#  dropout (Dropout)           (None, 84, 32)            0
#
#  lstm_1 (LSTM)               (None, 32)                8320
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None,
# 18/25 [====================>.........] - ETA: 0s - loss: 4.3526 - accuracy: 0.0148
# 19/25 [=====================>........] - ETA: 0s - loss: 4.3535 - accuracy: 0.0156
# 20/25 [=======================>......] - ETA: 0s - loss: 4.3544 - accuracy: 0.0152
# 21/25 [========================>.....] - ETA: 0s - loss: 4.3553 - accuracy: 0.0145
# 22/25 [=========================>....] - ETA: 0s - loss: 4.3559 - accuracy: 0.0142
# 23/25 [==========================>...] - ETA: 0s - loss: 4.3563 - accuracy: 0.0143
# 24/25 [===========================>..] - ETA: 0s - loss: 4.3571 - accuracy: 0.0143
# 25/25 [==============================] - ETA: 0s - loss: 4.3572 - accuracy: 0.0144
# 25/25 [==============================] - 3s 111ms/step - loss: 4.3572 - accuracy: 0.0144 - val_loss: 4.3568 - val_accuracy: 0.0128
# Saved LSTM model to /kaggle/working/prescription_lstm.h5
# Found 3120 validated image filenames belonging to 78 classes.
# Found 780 validated image filenames belonging to 78 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 21, 21, 16)        5824
#
#  max_pooling2d (MaxPooling2  (None, 11, 11, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        12832
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 6, 6, 48)          13872
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 64)          27712
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 64)          36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 512)               295424
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 78)                20046
#
# =================================================================
# Total params: 543966 (2.08 MB)
# Trainable params: 543966 (2.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/3
#
#  1/25 [>.............................] - ETA: 7:26 - loss: 4.3571 - accuracy: 0.0234
#  2/25 [=>............................] - ETA: 3s - loss: 4.3781 - accuracy: 0.0273
#  3/25 [==>...........................] - ETA: 3s - loss: 4.3689 - accuracy: 0.0208
#  4/25 [===>..........................] - ETA: 3s - loss: 4.3662 - accuracy: 0.0156
#  5/25 [=====>........................] - ETA: 2s - loss: 4.3694 - accuracy: 0.0141
#  6/25 [======>.......................] - ETA: 2s - loss: 4.3683 - accuracy: 0.0130
#  7/25 [=======>......................] - ETA: 2s - loss: 4.3667 - accuracy: 0.0134
#  8/25 [========>.....................] - ETA: 2s - loss: 4.3656 - accuracy: 0.0117
#  9/25 [=========>....................] - ETA: 2s - loss: 4.3656 - accuracy: 0.0122
# 10/25 [===========>..................] - ETA: 2s - loss: 4.3657 - accuracy: 0.0109
# 11/25 [============>.................] - ETA: 2s - loss: 4.3651 - accuracy: 0.0107
# 12/25 [=============>................] - ETA: 1s - loss: 4.3647 - accuracy: 0.0111
# 13/25 [==============>...............] - ETA: 1s - loss: 4.3644 - accuracy: 0.0120
# 14/25 [===============>..............] - ETA: 1s - loss: 4.3638 - accuracy: 0.0123
# 15/25 [=================>............] - ETA: 1s - loss: 4.3635 - accuracy: 0.0130
# 16/25 [==================>...........] - ETA: 1s - loss: 4.3634 - accuracy: 0.0122
# 25/25 [==============================] - 4s 158ms/step - loss: 4.3572 - accuracy: 0.0109 - val_loss: 4.3567 - val_accuracy: 0.0128
# Epoch 3/3
#
#  1/25 [>.............................] - ETA: 5s - loss: 4.3564 - accuracy: 0.0156
#  2/25 [=>............................] - ETA: 3s - loss: 4.3561 - accuracy: 0.0117
#  3/25 [==>...........................] - ETA: 3s - loss: 4.3563 - accuracy: 0.0130
#  4/25 [===>..........................] - ETA: 2s - loss: 4.3565 - accuracy: 0.0137
#  5/25 [=====>........................] - ETA: 2s - loss: 4.3565 - accuracy: 0.0109
#  6/25 [======>.......................] - ETA: 2s - loss: 4.3568 - accuracy: 0.0104
#  7/25 [=======>......................] - ETA: 2s - loss: 4.3569 - accuracy: 0.0100
#  8/25 [========>.....................] - ETA: 2s - loss: 4.3568 - accuracy: 0.0107
#  9/25 [=========>....................] - ETA: 2s - loss: 4.3570 - accuracy: 0.0113
# 10/25 [===========>..................] - ETA: 2s - loss: 4.3569 - accuracy: 0.0141
# 11/25 [============>.................] - ETA: 1s - loss: 4.3569 - accuracy: 0.0128
# 12/25 [=============>................] - ETA: 1s - loss: 4.3568 - accuracy: 0.0124
# 13/25 [==============>...............] - ETA: 1s - loss: 4.3569 - accuracy: 0.0114
# 14/25 [===============>..............] - ETA: 1s - loss: 4.3569 - accuracy: 0.0106
# 15/25 [=================>............] - ETA: 1s - loss: 4.3569 - accuracy: 0.0099
# 16/25 [==================>...........] - ETA: 1s - loss: 4.3569 - accuracy: 0.0107
# 17/25 [===================>..........] - ETA: 1s - loss: 4.3571 - accuracy: 0.0106
# 18/25 [====================>.........] - ETA: 0s - loss: 4.3571 - accuracy: 0.0113
# 19/25 [=====================>........] - ETA: 0s - loss: 4.3572 - accuracy: 0.0107
# 20/25 [=======================>......] - ETA: 0s - loss: 4.3572 - accuracy: 0.0102
# 21/25 [========================>.....] - ETA: 0s - loss: 4.3572 - accuracy: 0.0097
# 22/25 [=========================>....] - ETA: 0s - loss: 4.3572 - accuracy: 0.0096
# 23/25 [==========================>...] - ETA: 0s - loss: 4.3572 - accuracy: 0.0094
# 24/25 [===========================>..] - ETA: 0s - loss: 4.3573 - accuracy: 0.0094
# 25/25 [==============================] - ETA: 0s - loss: 4.3573 - accuracy: 0.0093
# 25/25 [==============================] - 4s 155ms/step - loss: 4.3573 - accuracy: 0.0093 - val_loss: 4.3567 - val_accuracy: 0.0128
# Saved AlexNet model to /kaggle/working/prescription_classification_alexnet.h5
# > /opt/conda/bin/python /kaggle/usr/lib/load_images/load_images.py --train-csv /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Training/training_labels.csv --train-dir /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Training/training_words --val-csv /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Validation/validation_labels.csv --val-dir /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Validation/validation_words --test-csv /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Testing/testing_labels.csv --test-dir /kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Testing/testing_words --out-dir data/processed
# > /opt/conda/bin/python /kaggle/usr/lib/train_cnn/train_cnn.py --data-dir data/processed --output /kaggle/working/prescription_classification_model.h5
# > /opt/conda/bin/python /kaggle/usr/lib/convert_tflite/convert_tflite.py --model /kaggle/working/prescription_classification_model.h5 --output /kaggle/working/prescription_classification_quantized.tflite
# > /opt/conda/bin/python /kaggle/usr/lib/train_lstm/train_lstm.py --data-dir data/processed --output /kaggle/working/prescription_lstm.h5
# > /opt/conda/bin/python /kaggle/usr/lib/train_alexnet/train_alexnet.py --data-dir data/processed --output /kaggle/working/prescription_classification_alexnet.h5
# All requested steps finished. Artifacts in /kaggle/working
#
# --- orchestrator stderr ---
# /opt/conda/lib/python3.10/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1769963088.951315     358 tf_tfl_flatbuffer_helpers.cc:390] Ignored output_format.
# W0000 00:00:1769963088.951426     358 tf_tfl_flatbuffer_helpers.cc:393] Ignored drop_control_dependency.
# /opt/conda/lib/python3.10/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /opt/conda/lib/python3.10/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load train/validation/test label CSVs
df_test = pd.read_csv('/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Testing/testing_labels.csv')
df_train = pd.read_csv('/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Training/training_labels.csv')
df_val = pd.read_csv('/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Validation/validation_labels.csv')

df_train.head()
# Out:
#    IMAGE MEDICINE_NAME GENERIC_NAME
# 0  0.png         Aceta  Paracetamol
# 1  1.png         Aceta  Paracetamol
# 2  2.png         Aceta  Paracetamol
# 3  3.png         Aceta  Paracetamol
# 4  4.png         Aceta  Paracetamol

# %%
df_train
# Out:
#          IMAGE MEDICINE_NAME            GENERIC_NAME
# 0        0.png         Aceta             Paracetamol
# 1        1.png         Aceta             Paracetamol
# 2        2.png         Aceta             Paracetamol
# 3        3.png         Aceta             Paracetamol
# 4        4.png         Aceta             Paracetamol
# ...        ...           ...                     ...
# 3115  3115.png       Zithrin  Azithromycin Dihydrate
# 3116  3116.png       Zithrin  Azithromycin Dihydrate
# 3117  3117.png       Zithrin  Azithromycin Dihydrate
# 3118  3118.png       Zithrin  Azithromycin Dihydrate
# 3119  3119.png       Zithrin  Azithromycin Dihydrate
#
# [3120 rows x 3 columns]

# %%
# Display a sample image (RGB for Matplotlib)
image_path = '/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Testing/testing_words/1.png'
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(6, 6))
plt.imshow(img_rgb)
plt.axis('off')
plt.title("Doctor's Handwritten Prescription")
plt.show()
print('Image shape:', img_rgb.shape)
# Out:
# Image shape: (84, 227, 3)

# %%
# Run image preprocessing to produce disk-backed data
print('Running image preprocessing to create data/processed...')
script_name = 'load_images.py'
try:
    script_path = resolve_script(script_name)
    print('Using script:', script_path)
    result = subprocess.run([
        sys.executable, str(script_path),
        '--train-csv', '/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Training/training_labels.csv',
        '--train-dir', '/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Training/training_words',
        '--val-csv', '/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Validation/validation_labels.csv',
        '--val-dir', '/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Validation/validation_words',
        '--test-csv', '/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Testing/testing_labels.csv',
        '--test-dir', '/kaggle/input/doctors-handwritten-prescription-bd-dataset/Doctor’s Handwritten Prescription BD dataset/Testing/testing_words',
        '--out-dir', 'data/processed',
    ], capture_output=True, text=True, check=True)
    print('Preprocessing completed')
    if result.stdout:
        print('--- preprocess stdout ---')
        print(result.stdout)
    if result.stderr:
        print('--- preprocess stderr ---')
        print(result.stderr)
    # Verify expected artifact
    test_path = PROCESSED_DIR / 'test_samples.npz'
    if not test_path.exists():
        raise FileNotFoundError(f'Preprocessing finished but required artifact missing: {test_path}')
    else:
        print('Verified test samples at', test_path)
except subprocess.CalledProcessError as e:
    print('Preprocessing script failed with returncode', e.returncode)
    print(e.stdout if e.stdout else '<no stdout>')
    print(e.stderr if e.stderr else '<no stderr>')
    raise
except FileNotFoundError as e:
    print(e)
    raise
# Out:
# Running image preprocessing to create data/processed...
# Using script: /kaggle/usr/lib/load_images/load_images.py
# Preprocessing completed
# --- preprocess stdout ---
# Saved processed images and labels to data/processed
#
# Verified test samples at data/processed/test_samples.npz

# %%
df_test["MEDICINE_NAME"]
# Out:
# 0        Aceta
# 1        Aceta
# 2        Aceta
# 3        Aceta
# 4        Aceta
#         ...
# 775    Zithrin
# 776    Zithrin
# 777    Zithrin
# 778    Zithrin
# 779    Zithrin
# Name: MEDICINE_NAME, Length: 780, dtype: object

# %%
arr=df_train['MEDICINE_NAME'].unique()
map1={}

for pos,key in enumerate(arr):
    map1[key]=pos

df_train['MEDICINE_NAME']=df_train['MEDICINE_NAME'].map(map1)
df_test['MEDICINE_NAME']=df_test['MEDICINE_NAME'].map(map1)
df_val['MEDICINE_NAME']=df_val['MEDICINE_NAME'].map(map1)

df_test['MEDICINE_NAME']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 775    77
# 776    77
# 777    77
# 778    77
# 779    77
# Name: MEDICINE_NAME, Length: 780, dtype: int64

# %%
def create_model():
    model = tf.keras.models.Sequential([ 
          tf.keras.layers.Conv2D(32, (3,3), activation='relu',input_shape=(84,84,3)),
          tf.keras.layers.MaxPooling2D(2,2),
          tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
          tf.keras.layers.MaxPooling2D(2,2),
          tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
          tf.keras.layers.MaxPooling2D(2,2),
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(512, activation='relu'),
          tf.keras.layers.Dropout(0.4),
          tf.keras.layers.Dense(78, activation='softmax')
      ])

    model.compile(loss='sparse_categorical_crossentropy',
                    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
                    metrics=['accuracy'])

    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 82, 82, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 41, 41, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 39, 39, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 19, 19, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 17, 17, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 78)                40014
#
# =================================================================
# Total params: 4328078 (16.51 MB)
# Trainable params: 4328078 (16.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Prepare labels and launch external CNN training
y_train = np.array(df_train['MEDICINE_NAME'])
y_val = np.array(df_val['MEDICINE_NAME'])
y_test = np.array(df_test['MEDICINE_NAME'])

print('Launching CNN training script (external)')
script_name = 'train_cnn.py'
try:
    script_path = resolve_script(script_name)
    print('Using script:', script_path)
    result = subprocess.run([
        sys.executable, str(script_path),
        '--data-dir', 'data/processed',
        '--output', '/kaggle/working/prescription_classification_model.h5',
        '--epochs', '15',
        '--batch-size', '128',
    ], capture_output=True, text=True, check=True)
    print('Training completed')
    if result.stdout:
        print('--- train stdout ---')
        print(result.stdout)
    if result.stderr:
        print('--- train stderr ---')
        print(result.stderr)
    # Verify deterministic history written by training script
    alt_hist = Path('/kaggle/working/prescription_classification_history.json')
    if not alt_hist.exists():
        raise FileNotFoundError(f'Training finished but deterministic history missing: {alt_hist}')
    with open(alt_hist) as f:
        hist_dict = json.load(f)
    class HistoryWrapper:
        def __init__(self, d):
            self.history = d
    history = HistoryWrapper(hist_dict)
    print('Loaded deterministic history from', alt_hist)
except subprocess.CalledProcessError as e:
    print('Training script failed with returncode', e.returncode)
    print(e.stdout if e.stdout else '<no stdout>')
    print(e.stderr if e.stderr else '<no stderr>')
    raise
except FileNotFoundError as e:
    print(e)
    raise
# Out:
# Launching CNN training script (external)
# Using script: /kaggle/usr/lib/train_cnn/train_cnn.py
# Training completed
# --- train stdout ---
# Found 3120 validated image filenames belonging to 78 classes.
# Found 780 validated image filenames belonging to 78 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 82, 82, 16)        448
#
#  max_pooling2d (MaxPooling2  (None, 41, 41, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 39, 39, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 19, 19, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 17, 17, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 78)                20046
#
# =================================================================
# Total params: 1092462 (4.17 MB)
# Trainable params: 1092462 (4.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1
# 22/25 [=========================>....] - ETA: 1s - loss: 3.3996 - accuracy: 0.1959
# 23/25 [==========================>...] - ETA: 0s - loss: 3.4021 - accuracy: 0.1976
# 24/25 [===========================>..] - ETA: 0s - loss: 3.3989 - accuracy: 0.1985
# 25/25 [==============================] - ETA: 0s - loss: 3.3892 - accuracy: 0.2016
# 25/25 [==============================] - 10s 416ms/step - loss: 3.3892 - accuracy: 0.2016 - val_loss: 3.3048 - val_accuracy: 0.2590
# Saved training history to /kaggle/working/prescription_classification_model.h5.history.json and /kaggle/working/prescription_classification_history.json
# Saved model to /kaggle/working/prescription_classification_model.h5
#
# --- train stderr ---
# /opt/conda/lib/python3.10/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#
# Loaded deterministic history from /kaggle/working/prescription_classification_history.json

# %%
# Plot training/validation loss (if `history` is available)
# If training wrote a deterministic history file, load it here to ensure `history` is populated.
if 'history' not in globals() or history is None:
    try:
        alt = Path('/kaggle/working/prescription_classification_history.json')
        if alt.exists():
            with open(alt) as f:
                hist_dict = json.load(f)
            class HistoryWrapper:
                def __init__(self, d):
                    self.history = d
            history = HistoryWrapper(hist_dict)
            print('Loaded deterministic history from', alt)
    except Exception as e:
        print('Failed to load deterministic history:', e)

if 'history' in globals() and history is not None and hasattr(history, 'history'):
    try:
        plt.figure(figsize=(10, 6))
        plt.plot(history.history.get('loss', []), label='Training Loss', color='blue')
        plt.plot(history.history.get('val_loss', []), label='Validation Loss', color='orange')
        plt.title('Bias-Variance Tradeoff')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid()
        plt.show()
    except Exception as e:
        print('Failed to plot history:', e)
else:
    print('`history` not found — run training to populate training history.')

# %%
# Artifact locations
print('Training scripts save models to /kaggle/working by default.')
print('CNN:   ', '/kaggle/working/prescription_classification_model.h5')
print('LSTM:  ', '/kaggle/working/prescription_lstm.h5')
print('AlexNet:', '/kaggle/working/prescription_classification_alexnet.h5')
# Out:
# Training scripts save models to /kaggle/working by default.
# CNN:    /kaggle/working/prescription_classification_model.h5
# LSTM:   /kaggle/working/prescription_lstm.h5
# AlexNet: /kaggle/working/prescription_classification_alexnet.h5

# %%
# Convert trained Keras model to TFLite using script
print('Converting Keras model to TFLite using script')
script_name = 'convert_tflite.py'
try:
    script_path = resolve_script(script_name)
    print('Using script:', script_path)
    subprocess.run([
        'python3', str(script_path),
        '--model', '/kaggle/working/prescription_classification_model.h5',
        '--output', '/kaggle/working/prescription_classification_quantized.tflite',
    ], check=True)
except FileNotFoundError as e:
    print(e)
# Out:
# Converting Keras model to TFLite using script
# Using script: /kaggle/usr/lib/convert_tflite/convert_tflite.py
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1769963382.032592     898 tf_tfl_flatbuffer_helpers.cc:390] Ignored output_format.
# W0000 00:00:1769963382.032646     898 tf_tfl_flatbuffer_helpers.cc:393] Ignored drop_control_dependency.
# Saved TFLite to /kaggle/working/prescription_classification_quantized.tflite

# %%
# Run external LSTM training script
print('Running LSTM training script (external)...')
script_name = 'train_lstm.py'
try:
    script_path = resolve_script(script_name)
    print('Using script:', script_path)
    subprocess.run([
        'python3', str(script_path),
        '--data-dir', 'data/processed',
        '--output', '/kaggle/working/prescription_lstm.h5',
        '--epochs', '3',
        '--batch-size', '128',
        '--size', '84',
    ], check=True)
except FileNotFoundError as e:
    print(e)
# Out:
# Running LSTM training script (external)...
# Using script: /kaggle/usr/lib/train_lstm/train_lstm.py
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 84, 32)            36480
#
#  dropout (Dropout)           (None, 84, 32)            0
#
#  lstm_1 (LSTM)               (None, 32)                8320
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 78)                2574
#
# =================================================================
# Total params: 51566 (201.43 KB)
# Trainable params: 51566 (201.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/3
# 25/25 [==============================] - 27s 177ms/step - loss: 4.3733 - accuracy: 0.0096 - val_loss: 4.3571 - val_accuracy: 0.0128
# Epoch 2/3
# 25/25 [==============================] - 3s 114ms/step - loss: 4.3601 - accuracy: 0.0115 - val_loss: 4.3568 - val_accuracy: 0.0141
# Epoch 3/3
# 25/25 [==============================] - 3s 114ms/step - loss: 4.3588 - accuracy: 0.0125 - val_loss: 4.3567 - val_accuracy: 0.0128
# Saved LSTM model to /kaggle/working/prescription_lstm.h5
# /opt/conda/lib/python3.10/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Run external AlexNet training script (robust runner)
print('Running AlexNet training script (external)')
script_name = 'train_alexnet.py'
try:
    script_path = resolve_script(script_name)
    print('Using script:', script_path)
    result = subprocess.run([
        sys.executable, str(script_path),
        '--data-dir', 'data/processed',
        '--output', '/kaggle/working/prescription_classification_alexnet.h5',
        '--epochs', '3',
        '--batch-size', '128',
        '--size', '84',
    ], capture_output=True, text=True, check=True)
    print('AlexNet completed successfully')
    if result.stdout:
        print('--- alexnet stdout ---')
        print(result.stdout)
    if result.stderr:
        print('--- alexnet stderr ---')
        print(result.stderr)
except subprocess.CalledProcessError as e:
    print(f'AlexNet script failed with returncode {e.returncode}')
    print('--- captured stdout ---')
    print(e.stdout if e.stdout else '<no stdout>')
    print('--- captured stderr ---')
    print(e.stderr if e.stderr else '<no stderr>')
    raise
except FileNotFoundError as e:
    print(e)
    raise
# Out:
# Running AlexNet training script (external)
# Using script: /kaggle/usr/lib/train_alexnet/train_alexnet.py
# AlexNet completed successfully
# --- alexnet stdout ---
# Found 3120 validated image filenames belonging to 78 classes.
# Found 780 validated image filenames belonging to 78 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 21, 21, 16)        5824
#
#  max_pooling2d (MaxPooling2  (None, 11, 11, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        12832
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 6, 6, 48)          13872
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 64)          27712
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 64)          36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 512)               295424
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 78)                20046
#
# =================================================================
# Total params: 543966 (2.08 MB)
# Trainable params: 543966 (2.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1
# 20/25 [=======================>......] - ETA: 0s - loss: 4.3570 - accuracy: 0.0141
# 21/25 [========================>.....] - ETA: 0s - loss: 4.3571 - accuracy: 0.0138
# 22/25 [=========================>....] - ETA: 0s - loss: 4.3571 - accuracy: 0.0139
# 23/25 [==========================>...] - ETA: 0s - loss: 4.3572 - accuracy: 0.0140
# 24/25 [===========================>..] - ETA: 0s - loss: 4.3572 - accuracy: 0.0140
# 25/25 [==============================] - ETA: 0s - loss: 4.3572 - accuracy: 0.0135
# 25/25 [==============================] - 4s 156ms/step - loss: 4.3572 - accuracy: 0.0135 - val_loss: 4.3567 - val_accuracy: 0.0128
# Saved AlexNet model to /kaggle/working/prescription_classification_alexnet.h5
#
# --- alexnet stderr ---
# /opt/conda/lib/python3.10/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Performance Audit: Benchmarking Inference Latency (will convert if needed)
tflite_path = Path('/kaggle/working/prescription_classification_quantized.tflite')
keras_path = Path('/kaggle/working/prescription_classification_model.h5')
interpreter = None
input_details = None
output_details = None
# If TFLite doesn't exist but Keras model does, convert it here (ensures CI works deterministically)
if not tflite_path.exists() and keras_path.exists():
    try:
        print('TFLite not found; converting Keras model to TFLite in-notebook...')
        keras_model_local = tf.keras.models.load_model(str(keras_path))
        converter = tf.lite.TFLiteConverter.from_keras_model(keras_model_local)
        # Use default optimization to get a quantized/optimized model where possible
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        tflite_model = converter.convert()
        with open(tflite_path, 'wb') as f:
            f.write(tflite_model)
        print('Converted and saved TFLite model to', tflite_path)
    except Exception as e:
        print('In-notebook TFLite conversion failed:', e)

# Create interpreter if TFLite exists
if tflite_path.exists():
    try:
        interpreter = tf.lite.Interpreter(model_path=str(tflite_path))
        interpreter.allocate_tensors()
        input_details = interpreter.get_input_details()
        output_details = interpreter.get_output_details()
    except Exception as e:
        print('Failed to create TFLite interpreter:', e)

# Try to load Keras model if available
keras_model = None
if keras_path.exists():
    try:
        keras_model = tf.keras.models.load_model(str(keras_path))
    except Exception as e:
        print('Failed to load Keras model:', e)

def measure_latency(model, input_data, iterations=50):
    """Measures average inference time (ms) for given model + input_data."""
    if model is None or input_data is None or len(input_data) == 0:
        raise ValueError('Model or input_data not available for latency measurement')
    total_time = 0.0
    n = min(iterations, len(input_data))
    for i in range(n):
        input_tensor = np.expand_dims(input_data[i], axis=0)
        start_time = time.time()
        # TFLite interpreter path
        if hasattr(model, 'invoke'):
            try:
                # Use the interpreter-specific input_details/output_details captured outside
                model.set_tensor(input_details[0]['index'], input_tensor.astype(np.float32))
                model.invoke()
                _ = model.get_tensor(output_details[0]['index'])
            except Exception as e:
                raise
        else:
            # Keras model path
            model.predict(input_tensor, verbose=0)
        end_time = time.time()
        total_time += (end_time - start_time)
    return (total_time / n) * 1000

# Determine test data to use
test_data = None
if 'test' in globals() and test is not None and len(test) > 0:
    test_data = test
else:
    # Attempt to load common artifact locations if preprocessing wrote an NPZ/NPY
    fallback_paths = [Path('data/processed/test_samples.npz'), Path('/kaggle/working/test_samples.npz'), Path('data/processed/test_samples.npy'), Path('/kaggle/working/test_samples.npy')]
    for fp in fallback_paths:
        try:
            if fp.exists():
                if fp.suffix == '.npz':
                    npz = np.load(str(fp), allow_pickle=True)
                    if 'test' in npz.files:
                        test_data = npz['test']
                    elif len(npz.files) > 0:
                        test_data = npz[npz.files[0]]
                    else:
                        continue
                else:
                    test_data = np.load(str(fp), allow_pickle=True)
                print('Loaded test data from', fp)
                break
        except Exception as e:
            print('Failed to load test from', fp, e)
    if test_data is None:
        raise RuntimeError('`test` dataset is required for performance audit — please run preprocessing to produce `data/processed/test_samples.npz`')

keras_latency = None
tflite_latency = None
# Measure Keras latency if model available
if keras_model is not None and test_data is not None:
    keras_latency = measure_latency(keras_model, test_data)
# Measure TFLite latency if interpreter available
if interpreter is not None and test_data is not None:
    tflite_latency = measure_latency(interpreter, test_data)

print('--- Deployment Readiness Audit ---')
print(f'Keras model present: {keras_model is not None}')
print(f'TFLite interpreter present: {interpreter is not None}')
if keras_latency is not None:
    print(f'Original Keras CNN Latency: {keras_latency:.2f} ms per image')
else:
    print('Keras latency: not measured')
if tflite_latency is not None:
    print(f'Quantized TFLite CNN Latency: {tflite_latency:.2f} ms per image')
else:
    print('TFLite latency: not measured')
if keras_latency is not None and tflite_latency is not None and tflite_latency > 0:
    print(f'Speedup: {keras_latency / tflite_latency:.2f}x')
else:
    print('Speedup: unavailable')
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Loaded test data from data/processed/test_samples.npz
# --- Deployment Readiness Audit ---
# Keras model present: True
# TFLite interpreter present: True
# Original Keras CNN Latency: 247.53 ms per image
# Quantized TFLite CNN Latency: 1.59 ms per image
# Speedup: 155.34x

# %%
# Compute model sizes and show a summary (fail fast if files missing)
original_model = Path('/kaggle/working/prescription_classification_model.h5')
quantized_model = Path('/kaggle/working/prescription_classification_quantized.tflite')
# Require both model files to exist for a meaningful summary
if not original_model.exists():
    raise FileNotFoundError(f'Missing original model: {original_model}')
if not quantized_model.exists():
    raise FileNotFoundError(f'Missing quantized model: {quantized_model}')
original_size = original_model.stat().st_size
quantized_size = quantized_model.stat().st_size
reduction = 100 * (1 - (quantized_size / original_size)) if original_size > 0 else 0.0
print('--- Optimization and Deployment Summary ---')
print('Successfully optimized the primary CNN model using Post-Training Quantization.')
print(f'Original size: {original_size / (1024**2):.2f} MB')
print(f'Quantized size: {quantized_size / (1024**2):.2f} MB')
print(f'Model Size Reduction: {reduction:.2f}%')
# Ensure latency numbers exist; otherwise compute them (may be slow) if test data is present
try:
    if 'keras_latency' not in globals() or keras_latency is None:
        if 'keras_model' in globals() and 'test_data' in globals() and test_data is not None:
            keras_latency = measure_latency(keras_model, test_data)
    if 'tflite_latency' not in globals() or tflite_latency is None:
        if 'interpreter' in globals() and interpreter is not None and 'test_data' in globals() and test_data is not None:
            tflite_latency = measure_latency(interpreter, test_data)
    print(f'Inference Speedup Achieved: {keras_latency / tflite_latency:.2f}x')
except Exception as e:
    print('Latency numbers unavailable or computation failed:', e)
# Out:
# --- Optimization and Deployment Summary ---
# Successfully optimized the primary CNN model using Post-Training Quantization.
# Original size: 8.38 MB
# Quantized size: 1.05 MB
# Model Size Reduction: 87.47%
# Inference Speedup Achieved: 155.34x

# %%
# Use OCR helpers from the Kaggle utility at a fixed path. Fail if missing.
kaggle_ocr = Path('/kaggle/usr/lib/ocr_helper/ocr_helper.py')
if not kaggle_ocr.exists():
    raise ImportError(f'OCR helper missing: {kaggle_ocr} — this notebook requires the Kaggle ocr_helper utility')
ocr_parent = str(kaggle_ocr.parent)
if ocr_parent not in sys.path:
    sys.path.insert(0, ocr_parent)
from ocr_helper import preprocess_image, extract_text_with_ocr, XYocr as XYocr_helper
def XYocr(folder):
    return XYocr_helper(folder, DATASET_ROOT)
print('Imported ocr_helper from', kaggle_ocr)
# Out:
# Imported ocr_helper from /kaggle/usr/lib/ocr_helper/ocr_helper.py

# %%
# BERT training (requires running the heavy-imports cell first)
# Uses `scripts/ocr_helper.XYocr` via the XYocr() wrapper imported earlier
xTrain, yTrain = XYocr('Training')
xVal, yVal = XYocr('Validation')
xTest, yTest = XYocr('Testing')

# Define character-level vocabulary
vocab_list = list('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ .,!?')
vocab = {char: i for i, char in enumerate(vocab_list, start=1)}
vocab['[PAD]'] = 0
vocab['[MASK]'] = len(vocab) + 1
vocab['[CLS]'] = len(vocab) + 2
vocab['[SEP]'] = len(vocab) + 3
vocab['[UNK]'] = len(vocab) + 4

# Save vocab
vocab_file = 'vocab.txt'
with open(vocab_file, 'w') as f:
    for token in vocab:
        f.write(token + '\n')

# Initialize tokenizer and datasets (heavy)
tokenizer = BertTokenizerFast(vocab_file=vocab_file)
tokenizer.pad_token = '[PAD]'
tokenizer.mask_token = '[MASK]'
tokenizer.cls_token = '[CLS]'
tokenizer.sep_token = '[SEP]'
tokenizer.unk_token = '[UNK]'
tokenizer_output_dir = 'output_tokenizer'
os.makedirs(tokenizer_output_dir, exist_ok=True)
tokenizer.save_pretrained(tokenizer_output_dir)

class CustomDataset(Dataset):
    def __init__(self, x_data, y_data, tokenizer, max_length=128):
        self.x_data = x_data
        self.y_data = y_data
        self.tokenizer = tokenizer
        self.max_length = max_length
    def __len__(self):
        return len(self.x_data)
    def __getitem__(self, idx):
        x = self.x_data[idx]
        y = self.y_data[idx]
        inputs = self.tokenizer(x, truncation=True, padding='max_length', max_length=self.max_length, return_tensors='pt')
        labels = self.tokenizer(y, truncation=True, padding='max_length', max_length=self.max_length, return_tensors='pt')
        return {
            'input_ids': inputs['input_ids'].squeeze(),
            'attention_mask': inputs['attention_mask'].squeeze(),
            'labels': labels['input_ids'].squeeze(),
        }

# Prepare datasets
train_dataset = CustomDataset(xTrain, yTrain, tokenizer)
val_dataset = CustomDataset(xVal, yVal, tokenizer)
test_dataset = CustomDataset(xTest, yTest, tokenizer)

# Build model config
config = BertConfig(vocab_size=len(vocab), hidden_size=256, num_hidden_layers=6, num_attention_heads=8, intermediate_size=512, max_position_embeddings=512)
model = BertForMaskedLM(config)
optimizer = AdamW(model.parameters(), lr=1e-4)
training_args = TrainingArguments(output_dir='output_model', num_train_epochs=3, per_device_train_batch_size=4, per_device_eval_batch_size=4, eval_strategy='epoch', save_strategy='epoch', logging_dir=None, logging_steps=1, report_to='none', save_steps=10, save_total_limit=1, load_best_model_at_end=True, disable_tqdm=False, fp16=False)

def compute_accuracy(p):
    preds, labels = p
    preds = torch.tensor(preds)
    preds = torch.argmax(preds, dim=-1)
    return {'accuracy': accuracy_score(labels.flatten(), preds.flatten())}

trainer = Trainer(model=model, args=training_args, train_dataset=train_dataset, eval_dataset=val_dataset, optimizers=(optimizer, None), compute_metrics=compute_accuracy)
trainer.train()
final_metrics = trainer.evaluate(val_dataset)
test_metrics = trainer.evaluate(test_dataset)
print(f"Final Test Accuracy: {test_metrics.get('eval_accuracy')}")
# Out:
# Processed 50/3120 images
# Processed 100/3120 images
# Processed 150/3120 images
# Processed 200/3120 images
# Processed 250/3120 images
# Processed 300/3120 images
# Processed 350/3120 images
# Processed 400/3120 images
# Processed 450/3120 images
# Processed 500/3120 images
# Processed 550/3120 images
# Processed 600/3120 images
# Processed 650/3120 images
# Processed 700/3120 images
# Processed 750/3120 images
# Processed 800/3120 images
# Processed 850/3120 images
# Processed 900/3120 images
# Processed 950/3120 images
# Processed 1000/3120 images
# Processed 1050/3120 images
# Processed 1100/3120 images
# Processed 1150/3120 images
# Processed 1200/3120 images
# Processed 1250/3120 images
# Processed 1300/3120 images
# Processed 1350/3120 images
# Processed 1400/3120 images
# Processed 1450/3120 images
# Processed 1500/3120 images
# Processed 1550/3120 images
# Processed 1600/3120 images
# Processed 1650/3120 images
# Processed 1700/3120 images
# Processed 1750/3120 images
# Processed 1800/3120 images
# Processed 1850/3120 images
# Processed 1900/3120 images
# Processed 1950/3120 images
# Processed 2000/3120 images
# Processed 2050/3120 images
# Processed 2100/3120 images
# Processed 2150/3120 images
# Processed 2200/3120 images
# Processed 2250/3120 images
# Processed 2300/3120 images
# Processed 2350/3120 images
# Processed 2400/3120 images
# Processed 2450/3120 images
# Processed 2500/3120 images
# Processed 2550/3120 images
# Processed 2600/3120 images
# Processed 2650/3120 images
# Processed 2700/3120 images
# Processed 2750/3120 images
# Processed 2800/3120 images
# Processed 2850/3120 images
# Processed 2900/3120 images
# Processed 2950/3120 images
# Processed 3000/3120 images
# Processed 3050/3120 images
# Processed 3100/3120 images
# Processed 3120/3120 images
# Processed 50/780 images
# Processed 100/780 images
# Processed 150/780 images
# Processed 200/780 images
# Processed 250/780 images
# Processed 300/780 images
# Processed 350/780 images
# Processed 400/780 images
# Processed 450/780 images
# Processed 500/780 images
# Processed 550/780 images
# Processed 600/780 images
# Processed 650/780 images
# Processed 700/780 images
# Processed 750/780 images
# Processed 780/780 images
# Processed 50/780 images
# Processed 100/780 images
# Processed 150/780 images
# Processed 200/780 images
# Processed 250/780 images
# Processed 300/780 images
# Processed 350/780 images
# Processed 400/780 images
# Processed 450/780 images
# Processed 500/780 images
# Processed 550/780 images
# Processed 600/780 images
# Processed 650/780 images
# Processed 700/780 images
# Processed 750/780 images
# BertForMaskedLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Processed 780/780 images
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='2340' max='2340' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2340/2340 07:16, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.016000</td>
#       <td>0.005541</td>
#       <td>0.999099</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.031600</td>
#       <td>0.004709</td>
#       <td>0.999099</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001300</td>
#       <td>0.004573</td>
#       <td>0.999099</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias'].
#     <div>
#
#       <progress value='390' max='195' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [195/195 00:21]
#     </div>
# Final Test Accuracy: 0.9990985576923077

# %%
# Clean up: Delete everything except data/processed
import shutil

work_dir = Path('/kaggle/working')
data_dir = work_dir / 'data'
processed_dir = data_dir / 'processed'

if work_dir.exists():
    print('Cleaning up /kaggle/working - keeping only data/processed')
    
    deleted_count = 0
    kept_count = 0
    
    # Iterate through all items in /kaggle/working
    for item in work_dir.iterdir():
        # Skip the data directory entirely
        if item.name == 'data':
            # Now handle the data directory - keep only processed
            if data_dir.exists():
                for data_item in data_dir.iterdir():
                    if data_item.name != 'processed':
                        if data_item.is_file():
                            data_item.unlink()
                            deleted_count += 1
                            print(f'Deleted: {data_item.relative_to(work_dir)}')
                        elif data_item.is_dir():
                            shutil.rmtree(data_item)
                            deleted_count += 1
                            print(f'Deleted: {data_item.relative_to(work_dir)}/')
                
                # Count files in processed
                if processed_dir.exists():
                    kept_count = sum(1 for _ in processed_dir.rglob('*') if _.is_file())
            continue
        
        # Delete everything else
        try:
            if item.is_file():
                item.unlink()
                deleted_count += 1
                print(f'Deleted: {item.name}')
            elif item.is_dir():
                shutil.rmtree(item)
                deleted_count += 1
                print(f'Deleted: {item.name}/')
        except Exception as e:
            print(f'Could not delete {item.name}: {e}')
    
    print(f'\n=== Cleanup Complete ===')
    print(f'Deleted: {deleted_count} items')
    print(f'Kept: {kept_count} files in data/processed')
    print(f'Final output: /kaggle/working/data/processed')
else:
    print('Working directory not found')
# Out:
# Cleaning up /kaggle/working - keeping only data/processed
# Deleted: output_model/
# Deleted: vocab.txt
# Deleted: prescription_classification_model.h5
# Deleted: __notebook__.ipynb
# Deleted: prescription_classification_alexnet.h5
# Deleted: prescription_classification_quantized.tflite
# Deleted: output_tokenizer/
# Deleted: prescription_classification_history.json
# Deleted: prescription_lstm.h5
# Deleted: prescription_classification_model.h5.history.json
#
# === Cleanup Complete ===
# Deleted: 10 items
# Kept: 4685 files in data/processed
# Final output: /kaggle/working/data/processed
